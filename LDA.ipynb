# %%
import warnings
warnings.filterwarnings('ignore')

import os
import gensim
import pyLDAvis
import pandas as pd
from gensim import corpora
from pyLDAvis import gensim as gensimvis
from timeit import default_timer as timer

# %%
file = 'LSTM.xlsx'
df = pd.read_excel(file, 'Sheet1', header=0, engine='openpyxl')
df
# Out:
#                                                 category  \
# 0      Artificial Intelligence, Machine Learning, Com...
# 1      Artificial Intelligence, Machine Learning, Com...
# 2      Artificial Intelligence, Machine Learning, Com...
# 3      Artificial Intelligence, Machine Learning, Com...
# 4      Artificial Intelligence, Machine Learning, Com...
# ...                                                  ...
# 16247            Web, Mobile and Multimedia Technologies
# 16248            Web, Mobile and Multimedia Technologies
# 16249            Web, Mobile and Multimedia Technologies
# 16250            Web, Mobile and Multimedia Technologies
# 16251            Web, Mobile and Multimedia Technologies
#
#                                                  content
# 0      replicated computation result report holistic ...
# 1      understanding assimilation contrast effect onl...
# 2      seasonal periodic subgraph mining temporal net...
# ...

# %%
texts = df.content.str.split()

dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

num_tokens = len(dictionary)
print('Number of unique tokens: %d' % num_tokens)

num_doc = len(corpus)
print('Number of documents: %d' % num_doc)
# Out:
# Number of unique tokens: 30924
# Number of documents: 16252

# %%
import warnings
warnings.filterwarnings('ignore')

NUM_TOPICS = 5
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=NUM_TOPICS, id2word=dictionary, passes=120)

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.save_html(vis, 'LDA_topic.html')
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.2.2/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1806426772003403362260140504"></div>
# <script type="text/javascript">
#
# ...
